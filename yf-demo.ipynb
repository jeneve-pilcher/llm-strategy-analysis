# %%
# not recommended for live trading?
import pandas as pd
import yfinance as yf

# %%
# https://ranaroussi.github.io/yfinance/reference/index.html

# %%
# ticker = stock name for company

company = yf.Tickers("MSFT")
data = company.history()
print(data.columns)
# Out:
# [*********************100%***********************]  1 of 1 completed
# MultiIndex([(       'Close', 'MSFT'),
#             (   'Dividends', 'MSFT'),
#             (        'High', 'MSFT'),
#             (         'Low', 'MSFT'),
#             (        'Open', 'MSFT'),
#             ('Stock Splits', 'MSFT'),
#             (      'Volume', 'MSFT')],
#            names=['Price', 'Ticker'])

# %%
data.head()
# Out:
# Price            Close Dividends        High         Low        Open  \
# Ticker            MSFT      MSFT        MSFT        MSFT        MSFT
# Date
# 2025-06-02  461.970001       0.0  462.109985  456.890015  457.140015
# 2025-06-03  462.970001       0.0  464.140015  460.859985  461.470001
# 2025-06-04  463.869995       0.0  465.690002  463.019989  464.000000
# 2025-06-05  467.679993       0.0  469.649994  464.029999  464.959991
# 2025-06-06  470.380005       0.0  473.339996  468.779999  470.089996
#
# Price      Stock Splits    Volume
# Ticker             MSFT      MSFT
# Date
# 2025-06-02          0.0  16626500
# 2025-06-03          0.0  15743800
# 2025-06-04          0.0  14162700
# 2025-06-05          0.0  20131700
# 2025-06-06          0.0  15285600

# %%
yf.Lookup("MSFT").all
# Out:
#           exchange                                      industryLink  \
# symbol
# MSFT           NMS       https://finance.yahoo.com/sector/technology
# MSFT.MX        MEX       https://finance.yahoo.com/sector/technology
# MSFU           NGM                                               NaN
# MSFD           NGM                                               NaN
# MSFO           PCX                                               NaN
# MSFT34.SA      SAO       https://finance.yahoo.com/sector/technology
# MSFT.NE        NEO       https://finance.yahoo.com/sector/technology
# O3CN.Z         ZRH                                               NaN
# ^MSFD-NV       ASE                                               NaN
# MSFT.BA        BUE       https://finance.yahoo.com/sector/technology
# MSFT.L         LSE                                               NaN
# 3SMF.L         LSE                                               NaN
# MSFY.NE        NEO                                               NaN
# MSFL           NGM                                               NaN
# ^MSFU-EU       ASE                                               NaN
# ^MSFD-TC       ASE                                               NaN
# ^MSFO-NV       ASE                                               NaN
# 46JL.Z         ZRH                                               NaN
# MSFT.SN        SGO       https://finance.yahoo.com/sector/technology
# MSFT.VI        VIE       https://finance.yahoo.com/sector/technology
# MSFT.TO        TOR       https://finance.yahoo.com/sector/technology
# MSFTCL.SN      SGO                                               NaN
# ^MSFU-TC       ASE                                               NaN
# ^MSFU-IV       ASE                                               NaN
# EVK.DU         DUS  https://finance.yahoo.com/sector/basic_materials
#
#               industryName quoteType   rank  regularMarketChange  \
# symbol
# MSFT            Technology    equity  27616            -1.944977
# MSFT.MX         Technology    equity  20082           -28.769531
# MSFU                   NaN       etf  20022            -0.430000
# MSFD                   NaN       etf  20013             0.059900
# MSFO                   NaN       etf  20006            -0.100401
# MSFT34.SA       Technology    equity  20006            -1.110001
# MSFT.NE         Technology    equity  20006            -0.590000
# O3CN.Z                 NaN     index  20002             1.690002
# ^MSFD-NV               NaN     index  20002             0.123200
# MSFT.BA         Technology    equity  20001           -25.000000
# MSFT.L                 NaN       etf  20001             2.500000
# 3SMF.L                 NaN       etf  20001             0.549999
# MSFY.NE                NaN       etf  20001            -0.400000
# MSFL                   NaN       etf  20001            -0.260099
# ^MSFU-EU               NaN     index  20001        -21444.562500
# ^MSFD-TC               NaN     index  20001          3080.968750
# ^MSFO-NV               NaN     index  20001            -0.141300
# 46JL.Z                 NaN     index  20001          -933.265625
# MSFT.SN         Technology    equity  20001             5.970001
# MSFT.VI         Technology    equity  20001            -1.000000
# MSFT.TO         Technology    equity  20001            -0.560001
# MSFTCL.SN              NaN    equity  20001         -9100.000000
# ^MSFU-TC               NaN     index  20001        -24894.250000
# ^MSFU-IV               NaN     index  20001            -0.404701
# EVK.DU     Basic Materials    equity  20001            -0.140001
#
#            regularMarketPercentChange  regularMarketPrice  \
# symbol
# MSFT                        -0.395280          490.105011
# MSFT.MX                     -0.311687         9201.500000
# MSFU                        -0.883502           48.220001
# MSFD                         0.526827           11.429900
# MSFO                        -0.567237           17.599600
# MSFT34.SA                   -0.992046          110.779999
# MSFT.NE                     -1.642997           35.320000
# O3CN.Z                       1.207403          141.729996
# ^MSFD-NV                     1.094638           11.378100
# MSFT.BA                     -0.123305        20225.000000
# MSFT.L                       0.340832          736.000000
# 3SMF.L                       1.494563           37.349998
# MSFY.NE                     -1.739129           22.600000
# MSFL                        -0.882291           29.219900
# ^MSFU-EU                    -2.155806       973290.750000
# ^MSFD-TC                     1.094976       284454.093750
# ^MSFO-NV                    -0.792766           17.682400
# 46JL.Z                      -1.162921        79280.687500
# MSFT.SN                      1.215688          497.049988
# MSFT.VI                     -0.238863          417.649994
# MSFT.TO                     -1.560762           35.320000
# MSFTCL.SN                   -1.956989       455900.000000
# ^MSFU-TC                    -2.501349       970338.500000
# ^MSFU-IV                    -0.831888           48.249699
# EVK.DU                      -0.799094           17.379999
#
#                                  shortName
# symbol
# MSFT                 Microsoft Corporation
# MSFT.MX                     MICROSOFT CORP
# MSFU       Direxion Daily MSFT Bull 2X Sha
# MSFD       Direxion Daily MSFT Bear 1X Sha
# MSFO       Tidal ETF Trust II YieldMax MSF
# MSFT34.SA                  MICROSOFT   DRN
# MSFT.NE         MICROSOFT CDR (CAD HEDGED)
# O3CN.Z     iSTX.Inve.Leveraged -3X MSFT  I
# ^MSFD-NV   DIREXION DAILY MSFT BEAR 1X SHA
# MSFT.BA    MICROSOFT CORP CEDEAR EACH 30 R
# MSFT.L     LEVERAGE SHARES PUBLIC LIMITED
# 3SMF.L     LEVERAGE SHARES PUBLIC LIMITED
# MSFY.NE    MICROSOFT (MSFT) YIELD SHARES P
# MSFL       GraniteShares 2x Long MSFT Dail
# ^MSFU-EU   DIREXION DAILY MSFT BULL 1.5X S
# ^MSFD-TC   DIREXION DAILY MSFT BEAR 1X SHA
# ^MSFO-NV   YIELDMAX MSFT OPTION INCOME STR
# 46JL.Z     iSTOXX Leveraged 3X MSFT      I
# MSFT.SN                     MICROSOFT CORP
# MSFT.VI                     MICROSOFT CORP
# MSFT.TO         MICROSOFT CDR (CAD HEDGED)
# MSFTCL.SN                   MICROSOFT CORP
# ^MSFU-TC   DIREXION DAILY MSFT BULL 1.5X S
# ^MSFU-IV   DIREXION DAILY MSFT BULL 1.5X S
# EVK.DU     Evonik Industries AG          N

# %%
yf.Lookup("MSFT").stock
# Out:
#           exchange                                      industryLink  \
# symbol
# MSFT           NMS       https://finance.yahoo.com/sector/technology
# MSFT.MX        MEX       https://finance.yahoo.com/sector/technology
# MSFT34.SA      SAO       https://finance.yahoo.com/sector/technology
# MSFT.NE        NEO       https://finance.yahoo.com/sector/technology
# MSFT.BA        BUE       https://finance.yahoo.com/sector/technology
# MSFT.SN        SGO       https://finance.yahoo.com/sector/technology
# MSFT.VI        VIE       https://finance.yahoo.com/sector/technology
# MSFT.TO        TOR       https://finance.yahoo.com/sector/technology
# MSFTCL.SN      SGO                                               NaN
# EVK.DU         DUS  https://finance.yahoo.com/sector/basic_materials
# MSFT.AS        AMS                                               NaN
# MSFTD.BA       BUE                                               NaN
# P47962.MI      MIL                                               NaN
# 10557.HK       HKG                                               NaN
# MSFT01.BK      SET       https://finance.yahoo.com/sector/technology
# MSFTC.BA       BUE                                               NaN
# YMSF.DE        GER                                               NaN
# MSFT80.BK      SET       https://finance.yahoo.com/sector/technology
# MSFT06.BK      SET                                               NaN
# MSFT.WA        WSE       https://finance.yahoo.com/sector/technology
#
#               industryName quoteType     rank  regularMarketChange  \
# symbol
# MSFT            Technology    equity  27616.0            -1.924988
# MSFT.MX         Technology    equity  20082.0           -28.769531
# MSFT34.SA       Technology    equity  20006.0            -1.120003
# MSFT.NE         Technology    equity  20006.0            -0.579998
# MSFT.BA         Technology    equity  20001.0           -25.000000
# MSFT.SN         Technology    equity  20001.0             5.970001
# MSFT.VI         Technology    equity  20001.0            -1.000000
# MSFT.TO         Technology    equity  20001.0            -0.560001
# MSFTCL.SN              NaN    equity  20001.0         -9100.000000
# EVK.DU     Basic Materials    equity  20001.0            -0.140001
# MSFT.AS                NaN    equity  20001.0            -0.036900
# MSFTD.BA               NaN    equity  20001.0            -0.100000
# P47962.MI              NaN    equity  20001.0            -0.519999
# 10557.HK               NaN    equity      NaN            -0.005000
# MSFT01.BK       Technology    equity      NaN            -0.060000
# MSFTC.BA               NaN    equity      NaN            -0.049999
# YMSF.DE                NaN    equity      NaN            -0.022500
# MSFT80.BK       Technology    equity      NaN            -0.100000
# MSFT06.BK              NaN    equity      NaN            -0.040000
# MSFT.WA         Technology    equity      NaN             0.000000
#
#            regularMarketPercentChange  regularMarketPrice  \
# symbol
# MSFT                        -0.391218          490.125000
# MSFT.MX                     -0.311687         9201.500000
# MSFT34.SA                   -1.000896          110.769997
# MSFT.NE                     -1.615593           35.330002
# MSFT.BA                     -0.123457        20225.000000
# MSFT.SN                      1.215688          497.049988
# MSFT.VI                     -0.238863          417.649994
# MSFT.TO                     -1.560762           35.320000
# MSFTCL.SN                   -1.956989       455900.000000
# EVK.DU                      -0.799094           17.379999
# MSFT.AS                     -0.432297            8.498800
# MSFTD.BA                    -0.606063           16.400000
# P47962.MI                   -2.349745           21.610001
# 10557.HK                    -1.666675            0.295000
# MSFT01.BK                   -1.260513            4.700000
# MSFTC.BA                    -0.303026           16.450001
# YMSF.DE                     -0.255886            8.770500
# MSFT80.BK                   -1.242241            7.950000
# MSFT06.BK                   -0.990098            4.000000
# MSFT.WA                      0.000000         1806.199951
#
#                                  shortName
# symbol
# MSFT                 Microsoft Corporation
# MSFT.MX                     MICROSOFT CORP
# MSFT34.SA                  MICROSOFT   DRN
# MSFT.NE         MICROSOFT CDR (CAD HEDGED)
# MSFT.BA    MICROSOFT CORP CEDEAR EACH 30 R
# MSFT.SN                     MICROSOFT CORP
# MSFT.VI                     MICROSOFT CORP
# MSFT.TO         MICROSOFT CDR (CAD HEDGED)
# MSFTCL.SN                   MICROSOFT CORP
# EVK.DU     Evonik Industries AG          N
# MSFT.AS        LS 1x Microsoft Tracker ETP
# MSFTD.BA   MICROSOFT CORP CEDEAR EACH 30 R
# P47962.MI  BPA TB LG MSFT 178,9 B178,9 OP
# 10557.HK                               NaN
# MSFT01.BK               MSFT01_DR MSFT#BLS
# MSFTC.BA   MICROSOFT CORP CEDEAR EACH 30 R
# YMSF.DE    Leverage Shares PLC           E
# MSFT80.BK               MSFT80_DR MSFT#KTB
# MSFT06.BK              MSFT06_DR MSFT#KKPS
# MSFT.WA                          MICROSOFT

# %%
yf.Lookup("MSFT").index
# Out:
#           exchange quoteType   rank  regularMarketChange  \
# symbol
# O3CN.Z         ZRH     index  20002             1.830002
# ^MSFD-NV       ASE     index  20002             0.123200
# ^MSFD-TC       ASE     index  20001          3080.968750
# ^MSFU-EU       ASE     index  20001        -21444.562500
# ^MSFO-NV       ASE     index  20001            -0.141300
# 46JL.Z         ZRH     index  20001         -1013.796875
# ^MSFU-TC       ASE     index  20001        -24894.250000
# ^MSFU-IV       ASE     index  20001            -0.401699
# ^MSFO-TC       ASE     index  20001         -3571.757812
# ^MSFU-NV       ASE     index  20001            -1.083099
# ^NY2LMSFT      NYS     index  20001           -11.351929
# ^MSFD-EU       ASE     index  20001          3080.968750
# ^MSFO-EU       ASE     index  20001            73.239746
# ^MSFD-IV       ASE     index  20001             0.047199
# 46J7.Z         ZRH     index  20001             0.250000
#
#            regularMarketPercentChange  regularMarketPrice  \
# symbol
# O3CN.Z                       1.307238          141.869995
# ^MSFD-NV                     1.094638           11.378100
# ^MSFD-TC                     1.094976       284454.093750
# ^MSFU-EU                    -2.155806       973290.750000
# ^MSFO-NV                    -0.792766           17.682400
# 46JL.Z                      -1.263418        79200.156250
# ^MSFU-TC                    -2.501349       970338.500000
# ^MSFU-IV                    -0.825785           48.252701
# ^MSFO-TC                    -5.823678        57759.890625
# ^MSFU-NV                    -2.177627           48.654499
# ^NY2LMSFT                   -0.816958         1378.127075
# ^MSFD-EU                     1.094976       284454.093750
# ^MSFO-EU                     1.387973         5349.979980
# ^MSFD-IV                     0.414774           11.425300
# 46J7.Z                       0.434103           57.840000
#
#                                  shortName
# symbol
# O3CN.Z     iSTX.Inve.Leveraged -3X MSFT  I
# ^MSFD-NV   DIREXION DAILY MSFT BEAR 1X SHA
# ^MSFD-TC   DIREXION DAILY MSFT BEAR 1X SHA
# ^MSFU-EU   DIREXION DAILY MSFT BULL 1.5X S
# ^MSFO-NV   YIELDMAX MSFT OPTION INCOME STR
# 46JL.Z     iSTOXX Leveraged 3X MSFT      I
# ^MSFU-TC   DIREXION DAILY MSFT BULL 1.5X S
# ^MSFU-IV   DIREXION DAILY MSFT BULL 1.5X S
# ^MSFO-TC   YIELDMAX MSFT OPTION INCOME STR
# ^MSFU-NV   DIREXION DAILY MSFT BULL 1.5X S
# ^NY2LMSFT      ICE Leveraged 2x MSFT Index
# ^MSFD-EU   DIREXION DAILY MSFT BEAR 1X SHA
# ^MSFO-EU   YIELDMAX MSFT OPTION INCOME STR
# ^MSFD-IV   DIREXION DAILY MSFT BEAR 1X SHA
# 46J7.Z     iSTOXX Inv.Leveraged -1X MSFT I
